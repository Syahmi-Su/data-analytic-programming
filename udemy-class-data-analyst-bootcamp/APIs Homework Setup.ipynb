# %%
# Import the relevant modules
import requests
import json

# %%
# The documentation for this particular API can be found here:
# https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/

# %%
# define base URL
base_site = "https://itunes.apple.com/search"

# %%
# Make a request
r = requests.get(base_site, params = {"term": "BROCKHAMPTON", "country": "us", "limit": 100})
r.status_code
# Out:
# 200

# %%
# Store the response
info = r.json()

# %% [markdown]
# ### Inspect the structure of the response

# %%
response = requests.get(base_site)
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Locate the name and release date of a song

# %%
import pandas as pd

# %%
songs_df = pd.DataFrame(info["results"])
songs_df
# Out:
#    wrapperType  kind   artistId  collectionId     trackId    artistName  \
# 0        track  song  960102996    1560866859  1560866864  BROCKHAMPTON
# 1        track  song  960102996    1560866859  1560866868  BROCKHAMPTON
# 2        track  song  960102996    1560866859  1560866862  BROCKHAMPTON
# 3        track  song  960102996    1560866859  1560866879  BROCKHAMPTON
# 4        track  song  960102996    1476858989  1476858991  BROCKHAMPTON
# ..         ...   ...        ...           ...         ...           ...
# 95       track  song  960102996    1269432891  1269432892  BROCKHAMPTON
# 96       track  song  960102996    1099993677  1099993868  BROCKHAMPTON
# 97       track  song  960102996    1099993677  1099993875  BROCKHAMPTON
# 98       track  song  960102996    1322093226  1322094240  BROCKHAMPTON
# 99       track  song  960102996    1322093226  1322094234  BROCKHAMPTON
#
#                         collectionName                   trackName  \
# 0   ROADRUNNER: NEW LIGHT, NEW MACHINE                 COUNT ON ME
# 1   ROADRUNNER: NEW LIGHT, NEW MACHINE                   THE LIGHT
# 2   ROADRUNNER: NEW LIGHT, NEW MACHINE  CHAIN ON (feat. JPEGMAFIA)
# 3   ROADRUNNER: NEW LIGHT, NEW MACHINE    DON'T SHOOT UP THE PARTY
# 4                               GINGER                       SUGAR
# ..                                 ...                         ...
# 95                      Swamp - Single                       Swamp
# 96                  All-American Trash                    Michigan
# 97                  All-American Trash                        Home
# 98                      SATURATION III                    CINEMA 3
# 99                      SATURATION III                      ALASKA
#
#                 collectionCensoredName           trackCensoredName  ...  \
# 0   ROADRUNNER: NEW LIGHT, NEW MACHINE                 COUNT ON ME  ...
# 1   ROADRUNNER: NEW LIGHT, NEW MACHINE                   THE LIGHT  ...
# 2   ROADRUNNER: NEW LIGHT, NEW MACHINE  CHAIN ON (feat. JPEGMAFIA)  ...
# 3   ROADRUNNER: NEW LIGHT, NEW MACHINE    DON'T SHOOT UP THE PARTY  ...
# 4                               GINGER                       SUGAR  ...
# ..                                 ...                         ...  ...
# 95                      Swamp - Single                       Swamp  ...
# 96                  All-American Trash                    Michigan  ...
# 97                  All-American Trash                        Home  ...
# 98                      SATURATION III                    CINEMA 3  ...
# 99                      SATURATION III                      ALASKA  ...
#
#    discCount discNumber trackCount trackNumber trackTimeMillis country  \
# 0          1          1         13           3          155200     USA
# 1          1          1         13           5          222787     USA
# 2          1          1         13           2          201253     USA
# 3          1          1         13          11          187267     USA
# 4          1          1         12           2          204542     USA
# ..       ...        ...        ...         ...             ...     ...
# 95         1          1          1           1          251964     USA
# 96         1          1         13           3          183562     USA
# 97         1          1         13          10          302393     USA
# 98         1          1         15          14           51206     USA
# 99         1          1         15           8          199195     USA
#
#    currency  primaryGenreName  contentAdvisoryRating isStreamable
# 0       USD       Hip-Hop/Rap               Explicit        False
# 1       USD       Hip-Hop/Rap               Explicit        False
# 2       USD       Hip-Hop/Rap               Explicit        False
# 3       USD       Hip-Hop/Rap               Explicit        False
# 4       USD       Hip-Hop/Rap               Explicit         True
# ..      ...               ...                    ...          ...
# 95      USD       Hip-Hop/Rap               Explicit         True
# 96      USD       Alternative               Explicit         True
# 97      USD       Alternative               Explicit         True
# 98      USD       Hip-Hop/Rap               Explicit         True
# 99      USD       Hip-Hop/Rap               Explicit         True
#
# [100 rows x 32 columns]

# %% [markdown]
# ### Print the name of all songs

# %% [markdown]
# ### Print out the release date of all songs
